# %% [markdown]
# # Tutorial 3: Initializing a large-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gstatsMCMC import Topography
from gstatsMCMC import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg

# %%
# load compiled bed elevation measurements
df = pd.read_csv('./Recovery.csv')

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['highvel_mask'].values.reshape(xx.shape)
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
bedmachine_bed = bedmap_surf - bedmachine_thickness

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmachine bed topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()

# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %%
plt.pcolormesh(xx,yy,cond_bed)
plt.axis('scaled')
# Out:
# (np.float64(-652000.0),
#  np.float64(-41500.0),
#  np.float64(745500.0),
#  np.float64(979000.0))

# %%
# normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
df_sampled = df.sample(frac=0.5, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed']

maxlag = 100000      # maximum range distance
n_lags = 70         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', 
                   n_lags=n_lags, maxlag=maxlag, normalize=False, 
                   model='matern', samples = 0.4)

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters
V1_p[1] = 1.3
V1_p[2] = 0.7

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# Out:
# [np.float64(87679.15793376301), 1.3, 0.7, 0]

# %%
# V1_p = [83251.42284193831, 1.8417237215825735, 0.9952450731725953, 0]

# %%
# load bed generated by Sequential Gaussian Simulation
sgs_bed = np.loadtxt('./sgs.txt')
thickness = bedmap_surf - sgs_bed
sgs_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, sgs_bed)

# %% [markdown]
# ### Then initiating the chain

# %% [markdown]
# #### Initiate an object of the class chain_crf

# %% [markdown]
# Let's first initiate the chain. Here, we created an object of the class chain_crf. This initialization process requires several input that are essential for later calculations

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %%
largeScaleChain = MCMC.chain_crf(xx, yy, sgs_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_region(update_in_region, region_mask)
# then please set up the loss function using either set_loss_type or set_loss_func
# an RandField object also need to be created correctly and passed in set_crf_data_weight(RF) and in run(n_iter, RF)

# %% [markdown]
# Now, the object 'largeScaleChain' have all the properties you have assigned in the initialization process. Try typing *largeScaleChain.xx* or *largeScaleChain.cond_bed*, or any other argument to check them.

# %%
plt.pcolormesh(xx, yy, largeScaleChain.initial_bed)
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx, yy, largeScaleChain.surf)
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx, yy, largeScaleChain.data_mask)
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx, yy, largeScaleChain.velx)
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx, yy, largeScaleChain.grounded_ice_mask)
plt.axis('scaled')
plt.colorbar()

# %% [markdown]
# The second function required, is *set_update_region*. In this function, the first boolean argument decide whether the MCMC update will be inside the high velocity, the second argument specify the exact region of high velocity (where the high_vel_mask == 1)

# %%
largeScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
plt.pcolormesh(xx,yy,highvel_mask)

# %% [markdown]
# We also want to specify how we want to define the loss function used in the chain.
#
# *map_func* determine the distribution of mass conservation residuals, whereas the *diff_func* determine the distribution of the difference between radar measurements and simulated topography. If the residuals has a Gaussian distribution, the corresponding function will be 'sumsquare'. If you do not want to include either of these loss, simple put *map_func = None* or *diff_func = None*.
#
# *sigma_mc* and *sigma_data* determine the standard deviation of the distribution of mass conservation residual or differences to radar data. *massConvInRegion* and *dataDiffInRegion* specify whether the two losses should be calculated for only inside the high velocity region or not

# %%
mc_res_bm = Topography.get_mass_conservation_residual(bedmachine_bed,bedmap_surf,velx,vely,dhdt,smb,resolution)

# %%
sigma3 = 2.6
xl3=np.linspace(-100, 100, num=1000)
gaussian_model=1/(sigma3*np.sqrt(2*np.pi))*np.exp(-0.5*np.square(xl3/sigma3))

# here, we filter mc_res_bm to only account for mass flux residuals inside the high velocity region
mc_res_bm_sr2 = mc_res_bm[highvel_mask==1]
mc_res_bm_sr2_f = mc_res_bm_sr2.flatten()
mc_res_bm_sr2_f = mc_res_bm_sr2_f[~np.isnan(mc_res_bm_sr2_f)]

plt.hist(mc_res_bm_sr2_f, bins=5000, facecolor='red', alpha=0.3,density=True,label='BM')
plt.plot(xl3, gaussian_model, color='Green',alpha=0.6, label='Gaussian distribution')
plt.xlim([-20,20]);

plt.legend()
plt.xlabel('mass conv residual');
plt.ylabel('Frequency');
plt.title('histogram of mass conservation residual')
plt.show()

# %% [markdown]
# Setting up the loss function for the large-scale chain. Here, we only use mass conservation residuals as the loss and ignore the different to bed elevation measurements, because the chains will always perserve the radar measurements.
#
# Use 'sumsquare' will set the loss function as sum of squared mass conservation residuals inside the high-velocity region, which represent the pdf of a Gaussian distribution with standard deviation 'sigma_mc'

# %%
largeScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=2.6, massConvInRegion=True)

# %% [markdown]
# To directly calculate the loss of BedMachine topography in terms of mass conservation residuals, we can directly calls:
#
# largeScaleChain.loss(mass_conservation_residuals, difference_to_radar_measurements)
#
# the _loss()_ function returns three values: the total loss, mass conservation loss (loss based on mass conservation residuals) and measurements data loss (loss based on differences between the topography and the radar measurements). The total loss equals mass conservation loss plus radar measurements loss.
#
# Because we only set-up the mass conservation loss, the difference_to_radar_measurements can be left out

# %%
largeScaleChain.loss(mc_res_bm, 0)
# Out:
# (np.float64(811537.8226854556), np.float64(811537.8226854556), 0.0)

# %% [markdown]
# For more information regarding these two functions, please check the documentation for MCMC.py

# %% [markdown]
# An example of setting up both mass conservation loss and measurements data loss
#
# largeScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=5, massConvInRegion=True,
#                              diff_func='sumsquare', sigma_data=10, dataDiffInRegion=True)
#
# Then the loss function will return different things
#
# largeScaleChain.loss(mc_res_bm, bedmachine_bed - cond_bed)
#
# will returns, for example
#
# (2206762.607690888, 139380.26325314105, 2067382.3444377468)
#
# Here, the three values represents the total loss, the mass conservation loss, and the radar measurements loss.

# %% [markdown]
# #### Initiate an object of the class RandField

# %% [markdown]
# Next step is to set up the parameters of the random field perturbation

# %%
#range_max and range_min changes topographies features' lateral scale
#by default, I set range_max to variogram range
range_max_x = V1_p[0] #in terms of meters in lateral dimension, regardless of resolution of the map
range_max_y = V1_p[0]
range_min_x = 10e3
range_min_y = 10e3
scale_min = 80 #in terms of meters in vertical dimension, how much you want to multiply the perturbation by
scale_max = 300
nugget_max = 0
random_field_model = 'Matern' # currently only supporting 'Gaussian' or 'Exponential'
isotropic = True
smoothness = V1_p[2]

rf1 = MCMC.RandField(range_min_x, range_max_x, range_min_y, range_max_y, scale_min, scale_max, nugget_max, random_field_model, isotropic, smoothness = smoothness)
# Out:
# Before using the `RandField` object in an MCMC chain or for field generation,
#  call function `set_block_sizes` to initialize block size ranges;
#  call function `set_weight_param` to set up conditional weighting parameters;
#  call function 'set_generation_method' to set up method used to generate random fields.

# %% [markdown]
# Then we can set up the size of the blocks used in the update

# %% [markdown]
# *set_block_sizes* function create a list of possible block sizes, which will be accessible via rf1.pairs after the function is called.
#
# *set_block_sizes* function also has an optional argument *steps*, it specify how many 'steps' between the min_block and max_block will be divided into. For example, for min_block_x = 20 and max_block_x = 50, steps = 4 will divide the range into [20, 30, 40, 50]. For min_block_y = 10 and max_block_y = 55, it will divide the range into [10, 25, 40, 55]. Then each size on the list for x will pair up with all size on the list for y, creating a list of following
#
# rf1.pairs = [[20,10],[20,25],[20,40],[20,55],[30,10],[30,25],[30,40],[30,55],[40,10],[40,25],[40,40],[40,55],[50,10],[50,25],[50,40],[50,55]]
#
# When randomly deciding the size of the block, one of the size on the list will be chosen and will be used

# %%
min_block_x = 80
max_block_x = 230
min_block_y = 50
max_block_y = 110
rf1.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Finally, if you wish to use conditional block update, then the RandField object requires specifying the logistic function used to calculate the conditioning weight of the random field

# %% [markdown]
# The logistic function is used to calculate the weight for conditioning to the edge of the block and the weight for conditioning to radar measurements. When updating the field, the weight will be 1 at conditioning data and block edges, and it logistically decays to 0 at location *max_dist* away from any conditioning data

# %%
logis_func_L = 2
logis_func_x0 = 0
logis_func_k = 6
logis_func_offset = 1
max_dist = V1_p[0] # set to the distance between two points on the map where the correlation vanish / is minimal

rf1.set_weight_param(logis_func_L, logis_func_x0, logis_func_k, logis_func_offset, max_dist, resolution)

# %% [markdown]
# Set the generation method using the original gstools random field generator or the spectral synthesis generator.

# %%
rf1.set_generation_method(spectral=True)

# %% [markdown]
# #### Run the Markov chain

# %% [markdown]
# At last, these information need to be known to the crf chain. The function *set_crf_data_weight* calculate the weight for conditioning to the radar measurements

# %%
largeScaleChain.set_crf_data_weight(rf1)
largeScaleChain.set_update_type('CRF_weight')

# %%
np.savetxt('./recovery_weight.txt', largeScaleChain.crf_data_weight)

# %%
largeScaleChain.crf_data_weight = np.loadtxt('./recovery_weight.txt')
largeScaleChain.set_update_type('CRF_weight')
# Out:
# The update block is set to conditional random field generated by calculating weights with logistic function

# %% [markdown]
# And then we can start the chain by specifying how many iterations it should go through

# %%
seed = 20251019
rng = np.random.default_rng(seed)

beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used  = largeScaleChain.run(n_iter=500, RF=rf1, rng_seed=rng, only_save_last_bed=True, info_per_iter = 100, progress_bar=True, plot=True)

# %%
np.savetxt('./trial_1/beds/bed0.txt', beds)

# %%
i = 5000
seed = 20251019
rng = np.random.default_rng(seed)
while i < 7_005_000:
    print(f'Run # {i//5000}')
    previous_bed = './trial_1/beds/bed' + str(i-5000) + '.txt'
    largeScaleChain.initial_bed = np.loadtxt(previous_bed)
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used  = largeScaleChain.run(n_iter=5000, RF=rf1, rng_seed=rng, only_save_last_bed=True, info_per_iter = 4000, progress_bar=False, plot=False)    
    current_bed = './trial_1/beds/bed' + str(i) + '.txt'
    current_loss = './trial_1/loss/loss' + str(i) + '.txt'
    current_step = './trial_1/steps/step' + str(i) + '.txt'
    np.savetxt(current_bed, beds)
    np.savetxt(current_loss, loss)
    np.savetxt(current_step, steps)
    del beds
    i += 5000
# Out:
# Run # 154
# i: 4000 mc loss: 1.774e+06 data loss: 0.000e+00 loss: 1.774e+06 acceptance rate: 0.22119470132466884
# Run # 155
# i: 4000 mc loss: 1.773e+06 data loss: 0.000e+00 loss: 1.773e+06 acceptance rate: 0.22469382654336417
# Run # 156
# i: 4000 mc loss: 1.772e+06 data loss: 0.000e+00 loss: 1.772e+06 acceptance rate: 0.22894276430892277
# Run # 157
# i: 4000 mc loss: 1.771e+06 data loss: 0.000e+00 loss: 1.771e+06 acceptance rate: 0.21594601349662584
# Run # 158
# i: 4000 mc loss: 1.770e+06 data loss: 0.000e+00 loss: 1.770e+06 acceptance rate: 0.22594351412146962
# Run # 159
# i: 4000 mc loss: 1.769e+06 data loss: 0.000e+00 loss: 1.769e+06 acceptance rate: 0.2226943264183954
# Run # 160
# i: 4000 mc loss: 1.768e+06 data loss: 0.000e+00 loss: 1.768e+06 acceptance rate: 0.21619595101224695
# Run # 161
# i: 4000 mc loss: 1.767e+06 data loss: 0.000e+00 loss: 1.767e+06 acceptance rate: 0.213696575856036
# Run # 162
# i: 4000 mc loss: 1.766e+06 data loss: 0.000e+00 loss: 1.766e+06 acceptance rate: 0.21569607598100474
# Run # 163
# i: 4000 mc loss: 1.765e+06 data loss: 0.000e+00 loss: 1.765e+06 acceptance rate: 0.2026993251687078
# Run # 164
# i: 4000 mc loss: 1.764e+06 data loss: 0.000e+00 loss: 1.764e+06 acceptance rate: 0.2224443889027743
# Run # 165
# i: 4000 mc loss: 1.763e+06 data loss: 0.000e+00 loss: 1.763e+06 acceptance rate: 0.2271932016995751
# Run # 166
# i: 4000 mc loss: 1.762e+06 data loss: 0.000e+00 loss: 1.762e+06 acceptance rate: 0.21569607598100474
# Run # 167
# i: 4000 mc loss: 1.762e+06 data loss: 0.000e+00 loss: 1.762e+06 acceptance rate: 0.21094726318420395
# Run # 168
# i: 4000 mc loss: 1.761e+06 data loss: 0.000e+00 loss: 1.761e+06 acceptance rate: 0.21694576355911022
# Run # 169
# i: 4000 mc loss: 1.760e+06 data loss: 0.000e+00 loss: 1.760e+06 acceptance rate: 0.21194701324668833
# Run # 170
# i: 4000 mc loss: 1.759e+06 data loss: 0.000e+00 loss: 1.759e+06 acceptance rate: 0.22544363909022744
# Run # 171
# i: 4000 mc loss: 1.758e+06 data loss: 0.000e+00 loss: 1.758e+06 acceptance rate: 0.21194701324668833
# Run # 172
# i: 4000 mc loss: 1.758e+06 data loss: 0.000e+00 loss: 1.758e+06 acceptance rate: 0.22619345163709073
# Run # 173
# i: 4000 mc loss: 1.757e+06 data loss: 0.000e+00 loss: 1.757e+06 acceptance rate: 0.21569607598100474
# Run # 174
# i: 4000 mc loss: 1.756e+06 data loss: 0.000e+00 loss: 1.756e+06 acceptance rate: 0.21219695076230943
# Run # 175
# i: 4000 mc loss: 1.755e+06 data loss: 0.000e+00 loss: 1.755e+06 acceptance rate: 0.21919520119970007
# Run # 176
# i: 4000 mc loss: 1.754e+06 data loss: 0.000e+00 loss: 1.754e+06 acceptance rate: 0.2264433891527118
# Run # 177
# i: 4000 mc loss: 1.754e+06 data loss: 0.000e+00 loss: 1.754e+06 acceptance rate: 0.2219445138715321
# Run # 178
# i: 4000 mc loss: 1.753e+06 data loss: 0.000e+00 loss: 1.753e+06 acceptance rate: 0.20969757560609847
# Run # 179
# i: 4000 mc loss: 1.752e+06 data loss: 0.000e+00 loss: 1.752e+06 acceptance rate: 0.2079480129967508
# Run # 180
# i: 4000 mc loss: 1.751e+06 data loss: 0.000e+00 loss: 1.751e+06 acceptance rate: 0.21419645088727818
# Run # 181
# i: 4000 mc loss: 1.750e+06 data loss: 0.000e+00 loss: 1.750e+06 acceptance rate: 0.2129467633091727
# Run # 182
# i: 4000 mc loss: 1.750e+06 data loss: 0.000e+00 loss: 1.750e+06 acceptance rate: 0.20969757560609847
# Run # 183
# i: 4000 mc loss: 1.749e+06 data loss: 0.000e+00 loss: 1.749e+06 acceptance rate: 0.20819795051237192
# Run # 184
# i: 4000 mc loss: 1.748e+06 data loss: 0.000e+00 loss: 1.748e+06 acceptance rate: 0.21219695076230943
# Run # 185
# i: 4000 mc loss: 1.747e+06 data loss: 0.000e+00 loss: 1.747e+06 acceptance rate: 0.20669832541864533
# Run # 186
# i: 4000 mc loss: 1.747e+06 data loss: 0.000e+00 loss: 1.747e+06 acceptance rate: 0.21619595101224695
# Run # 187
# i: 4000 mc loss: 1.746e+06 data loss: 0.000e+00 loss: 1.746e+06 acceptance rate: 0.21169707573106725
# Run # 188
# i: 4000 mc loss: 1.745e+06 data loss: 0.000e+00 loss: 1.745e+06 acceptance rate: 0.21219695076230943
# Run # 189
# i: 4000 mc loss: 1.745e+06 data loss: 0.000e+00 loss: 1.745e+06 acceptance rate: 0.20294926268432892
# Run # 190
# i: 4000 mc loss: 1.744e+06 data loss: 0.000e+00 loss: 1.744e+06 acceptance rate: 0.2091977005748563
# Run # 191
# i: 4000 mc loss: 1.743e+06 data loss: 0.000e+00 loss: 1.743e+06 acceptance rate: 0.20894776305923518
# Run # 192
# i: 4000 mc loss: 1.742e+06 data loss: 0.000e+00 loss: 1.742e+06 acceptance rate: 0.21469632591852036
# Run # 193
# i: 4000 mc loss: 1.742e+06 data loss: 0.000e+00 loss: 1.742e+06 acceptance rate: 0.21269682579355162
# Run # 194
# i: 4000 mc loss: 1.741e+06 data loss: 0.000e+00 loss: 1.741e+06 acceptance rate: 0.22994251437140714
# Run # 195
# i: 4000 mc loss: 1.740e+06 data loss: 0.000e+00 loss: 1.740e+06 acceptance rate: 0.21519620094976255
# Run # 196
# i: 4000 mc loss: 1.739e+06 data loss: 0.000e+00 loss: 1.739e+06 acceptance rate: 0.21919520119970007
# Run # 197
# i: 4000 mc loss: 1.739e+06 data loss: 0.000e+00 loss: 1.739e+06 acceptance rate: 0.2086978255436141
# Run # 198
# i: 4000 mc loss: 1.738e+06 data loss: 0.000e+00 loss: 1.738e+06 acceptance rate: 0.21469632591852036
# Run # 199
# i: 4000 mc loss: 1.737e+06 data loss: 0.000e+00 loss: 1.737e+06 acceptance rate: 0.21194701324668833
# Run # 200
# i: 4000 mc loss: 1.736e+06 data loss: 0.000e+00 loss: 1.736e+06 acceptance rate: 0.20719820044988752
# Run # 201
# i: 4000 mc loss: 1.736e+06 data loss: 0.000e+00 loss: 1.736e+06 acceptance rate: 0.20994751312171958
# Run # 202
# i: 4000 mc loss: 1.735e+06 data loss: 0.000e+00 loss: 1.735e+06 acceptance rate: 0.21044738815296177
# Run # 203
# i: 4000 mc loss: 1.734e+06 data loss: 0.000e+00 loss: 1.734e+06 acceptance rate: 0.21419645088727818
# Run # 204
# i: 4000 mc loss: 1.734e+06 data loss: 0.000e+00 loss: 1.734e+06 acceptance rate: 0.20569857535616096
# Run # 205
# i: 4000 mc loss: 1.733e+06 data loss: 0.000e+00 loss: 1.733e+06 acceptance rate: 0.2079480129967508
# Run # 206
# i: 4000 mc loss: 1.732e+06 data loss: 0.000e+00 loss: 1.732e+06 acceptance rate: 0.2034491377155711
# Run # 207
# i: 4000 mc loss: 1.732e+06 data loss: 0.000e+00 loss: 1.732e+06 acceptance rate: 0.2274431392151962
# Run # 208
# i: 4000 mc loss: 1.731e+06 data loss: 0.000e+00 loss: 1.731e+06 acceptance rate: 0.2179455136215946
# Run # 209
# i: 4000 mc loss: 1.730e+06 data loss: 0.000e+00 loss: 1.730e+06 acceptance rate: 0.20744813796550862
# Run # 210
# i: 4000 mc loss: 1.730e+06 data loss: 0.000e+00 loss: 1.730e+06 acceptance rate: 0.20119970007498125
# Run # 211
# i: 4000 mc loss: 1.729e+06 data loss: 0.000e+00 loss: 1.729e+06 acceptance rate: 0.21544613846538366
# Run # 212
# i: 4000 mc loss: 1.728e+06 data loss: 0.000e+00 loss: 1.728e+06 acceptance rate: 0.20119970007498125
# Run # 213
# i: 4000 mc loss: 1.728e+06 data loss: 0.000e+00 loss: 1.728e+06 acceptance rate: 0.195201199700075
# Run # 214
# i: 4000 mc loss: 1.727e+06 data loss: 0.000e+00 loss: 1.727e+06 acceptance rate: 0.20694826293426644
# Run # 215
# i: 4000 mc loss: 1.727e+06 data loss: 0.000e+00 loss: 1.727e+06 acceptance rate: 0.21669582604348914
# Run # 216
# i: 4000 mc loss: 1.726e+06 data loss: 0.000e+00 loss: 1.726e+06 acceptance rate: 0.20694826293426644
# Run # 217
# i: 4000 mc loss: 1.725e+06 data loss: 0.000e+00 loss: 1.725e+06 acceptance rate: 0.20619845038740314
# Run # 218
# i: 4000 mc loss: 1.725e+06 data loss: 0.000e+00 loss: 1.725e+06 acceptance rate: 0.208447888027993
# Run # 219
# i: 4000 mc loss: 1.724e+06 data loss: 0.000e+00 loss: 1.724e+06 acceptance rate: 0.213696575856036
# Run # 220
# i: 4000 mc loss: 1.723e+06 data loss: 0.000e+00 loss: 1.723e+06 acceptance rate: 0.20194951262184455
# Run # 221
# i: 4000 mc loss: 1.723e+06 data loss: 0.000e+00 loss: 1.723e+06 acceptance rate: 0.21694576355911022
# Run # 222
# i: 4000 mc loss: 1.722e+06 data loss: 0.000e+00 loss: 1.722e+06 acceptance rate: 0.19670082479380155
# Run # 223
# i: 4000 mc loss: 1.722e+06 data loss: 0.000e+00 loss: 1.722e+06 acceptance rate: 0.20169957510622344
# Run # 224
# i: 4000 mc loss: 1.721e+06 data loss: 0.000e+00 loss: 1.721e+06 acceptance rate: 0.2184453886528368
# Run # 225
# i: 4000 mc loss: 1.721e+06 data loss: 0.000e+00 loss: 1.721e+06 acceptance rate: 0.20244938765308673
# Run # 226
# i: 4000 mc loss: 1.720e+06 data loss: 0.000e+00 loss: 1.720e+06 acceptance rate: 0.21719570107473132
# Run # 227
# i: 4000 mc loss: 1.719e+06 data loss: 0.000e+00 loss: 1.719e+06 acceptance rate: 0.20169957510622344
# Run # 228
# i: 4000 mc loss: 1.719e+06 data loss: 0.000e+00 loss: 1.719e+06 acceptance rate: 0.2139465133716571
# Run # 229
# i: 4000 mc loss: 1.718e+06 data loss: 0.000e+00 loss: 1.718e+06 acceptance rate: 0.2086978255436141
# Run # 230
# i: 4000 mc loss: 1.718e+06 data loss: 0.000e+00 loss: 1.718e+06 acceptance rate: 0.1987003249187703
# Run # 231
# i: 4000 mc loss: 1.717e+06 data loss: 0.000e+00 loss: 1.717e+06 acceptance rate: 0.21694576355911022
# Run # 232
# i: 4000 mc loss: 1.717e+06 data loss: 0.000e+00 loss: 1.717e+06 acceptance rate: 0.22119470132466884
# Run # 233
# i: 4000 mc loss: 1.716e+06 data loss: 0.000e+00 loss: 1.716e+06 acceptance rate: 0.213696575856036
# Run # 234
# i: 4000 mc loss: 1.716e+06 data loss: 0.000e+00 loss: 1.716e+06 acceptance rate: 0.19670082479380155
# Run # 235
# i: 4000 mc loss: 1.715e+06 data loss: 0.000e+00 loss: 1.715e+06 acceptance rate: 0.20294926268432892
# Run # 236
# i: 4000 mc loss: 1.715e+06 data loss: 0.000e+00 loss: 1.715e+06 acceptance rate: 0.19570107473131718
# Run # 237
# i: 4000 mc loss: 1.714e+06 data loss: 0.000e+00 loss: 1.714e+06 acceptance rate: 0.21044738815296177
# Run # 238
# i: 4000 mc loss: 1.713e+06 data loss: 0.000e+00 loss: 1.713e+06 acceptance rate: 0.21344663834041488
# Run # 239
# i: 4000 mc loss: 1.713e+06 data loss: 0.000e+00 loss: 1.713e+06 acceptance rate: 0.20644838790302425
# Run # 240
# i: 4000 mc loss: 1.712e+06 data loss: 0.000e+00 loss: 1.712e+06 acceptance rate: 0.19995001249687577
# Run # 241
# i: 4000 mc loss: 1.712e+06 data loss: 0.000e+00 loss: 1.712e+06 acceptance rate: 0.21944513871532118
# Run # 242
# i: 4000 mc loss: 1.711e+06 data loss: 0.000e+00 loss: 1.711e+06 acceptance rate: 0.22019495126218444
# Run # 243
# i: 4000 mc loss: 1.710e+06 data loss: 0.000e+00 loss: 1.710e+06 acceptance rate: 0.2091977005748563
# Run # 244
# i: 4000 mc loss: 1.710e+06 data loss: 0.000e+00 loss: 1.710e+06 acceptance rate: 0.2124468882779305
# Run # 245
# i: 4000 mc loss: 1.709e+06 data loss: 0.000e+00 loss: 1.709e+06 acceptance rate: 0.1982004498875281
# Run # 246
# i: 4000 mc loss: 1.709e+06 data loss: 0.000e+00 loss: 1.709e+06 acceptance rate: 0.20594851287178206
# Run # 247
# i: 4000 mc loss: 1.708e+06 data loss: 0.000e+00 loss: 1.708e+06 acceptance rate: 0.20719820044988752
# Run # 248
# i: 4000 mc loss: 1.708e+06 data loss: 0.000e+00 loss: 1.708e+06 acceptance rate: 0.20744813796550862
# Run # 249
# i: 4000 mc loss: 1.707e+06 data loss: 0.000e+00 loss: 1.707e+06 acceptance rate: 0.21419645088727818
# Run # 250
# i: 4000 mc loss: 1.707e+06 data loss: 0.000e+00 loss: 1.707e+06 acceptance rate: 0.20644838790302425
# Run # 251
# i: 4000 mc loss: 1.706e+06 data loss: 0.000e+00 loss: 1.706e+06 acceptance rate: 0.2034491377155711
# Run # 252
# i: 4000 mc loss: 1.706e+06 data loss: 0.000e+00 loss: 1.706e+06 acceptance rate: 0.21494626343414147
# Run # 253
# i: 4000 mc loss: 1.705e+06 data loss: 0.000e+00 loss: 1.705e+06 acceptance rate: 0.21269682579355162
# Run # 254
# i: 4000 mc loss: 1.705e+06 data loss: 0.000e+00 loss: 1.705e+06 acceptance rate: 0.2034491377155711
# Run # 255
# i: 4000 mc loss: 1.704e+06 data loss: 0.000e+00 loss: 1.704e+06 acceptance rate: 0.20194951262184455
# Run # 256
# i: 4000 mc loss: 1.704e+06 data loss: 0.000e+00 loss: 1.704e+06 acceptance rate: 0.213696575856036
# Run # 257
# i: 4000 mc loss: 1.703e+06 data loss: 0.000e+00 loss: 1.703e+06 acceptance rate: 0.2041989502624344
# Run # 258
# i: 4000 mc loss: 1.703e+06 data loss: 0.000e+00 loss: 1.703e+06 acceptance rate: 0.1987003249187703
# Run # 259
# i: 4000 mc loss: 1.702e+06 data loss: 0.000e+00 loss: 1.702e+06 acceptance rate: 0.1939515121219695
# Run # 260
# i: 4000 mc loss: 1.702e+06 data loss: 0.000e+00 loss: 1.702e+06 acceptance rate: 0.19770057485628592
# Run # 261
# i: 4000 mc loss: 1.701e+06 data loss: 0.000e+00 loss: 1.701e+06 acceptance rate: 0.2139465133716571
# Run # 262
# i: 4000 mc loss: 1.701e+06 data loss: 0.000e+00 loss: 1.701e+06 acceptance rate: 0.2124468882779305
# Run # 263
# i: 4000 mc loss: 1.700e+06 data loss: 0.000e+00 loss: 1.700e+06 acceptance rate: 0.19220194951262184
# Run # 264
# i: 4000 mc loss: 1.700e+06 data loss: 0.000e+00 loss: 1.700e+06 acceptance rate: 0.20144963759060236
# Run # 265
# i: 4000 mc loss: 1.699e+06 data loss: 0.000e+00 loss: 1.699e+06 acceptance rate: 0.20294926268432892
# Run # 266
# i: 4000 mc loss: 1.699e+06 data loss: 0.000e+00 loss: 1.699e+06 acceptance rate: 0.195201199700075
# Run # 267
# i: 4000 mc loss: 1.698e+06 data loss: 0.000e+00 loss: 1.698e+06 acceptance rate: 0.2034491377155711
# Run # 268
# i: 4000 mc loss: 1.698e+06 data loss: 0.000e+00 loss: 1.698e+06 acceptance rate: 0.19845038740314921
# Run # 269
# i: 4000 mc loss: 1.698e+06 data loss: 0.000e+00 loss: 1.698e+06 acceptance rate: 0.20219945013746563
# Run # 270
# i: 4000 mc loss: 1.697e+06 data loss: 0.000e+00 loss: 1.697e+06 acceptance rate: 0.20144963759060236
# Run # 271
# i: 4000 mc loss: 1.697e+06 data loss: 0.000e+00 loss: 1.697e+06 acceptance rate: 0.20469882529367658
# Run # 272
# i: 4000 mc loss: 1.696e+06 data loss: 0.000e+00 loss: 1.696e+06 acceptance rate: 0.21094726318420395
# Run # 273
# i: 4000 mc loss: 1.696e+06 data loss: 0.000e+00 loss: 1.696e+06 acceptance rate: 0.19695076230942266
# Run # 274
# i: 4000 mc loss: 1.696e+06 data loss: 0.000e+00 loss: 1.696e+06 acceptance rate: 0.20594851287178206
# Run # 275
# i: 4000 mc loss: 1.695e+06 data loss: 0.000e+00 loss: 1.695e+06 acceptance rate: 0.19720069982504373
# Run # 276
# i: 4000 mc loss: 1.695e+06 data loss: 0.000e+00 loss: 1.695e+06 acceptance rate: 0.21044738815296177
# Run # 277
# i: 4000 mc loss: 1.694e+06 data loss: 0.000e+00 loss: 1.694e+06 acceptance rate: 0.20469882529367658
# Run # 278
# i: 4000 mc loss: 1.694e+06 data loss: 0.000e+00 loss: 1.694e+06 acceptance rate: 0.21869532616845788
# Run # 279
# i: 4000 mc loss: 1.693e+06 data loss: 0.000e+00 loss: 1.693e+06 acceptance rate: 0.20769807548112973
# Run # 280
# i: 4000 mc loss: 1.693e+06 data loss: 0.000e+00 loss: 1.693e+06 acceptance rate: 0.20994751312171958
# Run # 281
# i: 4000 mc loss: 1.692e+06 data loss: 0.000e+00 loss: 1.692e+06 acceptance rate: 0.1992001999500125
# Run # 282
# i: 4000 mc loss: 1.692e+06 data loss: 0.000e+00 loss: 1.692e+06 acceptance rate: 0.20469882529367658
# Run # 283
# i: 4000 mc loss: 1.692e+06 data loss: 0.000e+00 loss: 1.692e+06 acceptance rate: 0.1982004498875281
# Run # 284
# i: 4000 mc loss: 1.691e+06 data loss: 0.000e+00 loss: 1.691e+06 acceptance rate: 0.19070232441889529
# Run # 285
# i: 4000 mc loss: 1.691e+06 data loss: 0.000e+00 loss: 1.691e+06 acceptance rate: 0.20494876280929766
# Run # 286
# i: 4000 mc loss: 1.691e+06 data loss: 0.000e+00 loss: 1.691e+06 acceptance rate: 0.195201199700075
# Run # 287
# i: 4000 mc loss: 1.690e+06 data loss: 0.000e+00 loss: 1.690e+06 acceptance rate: 0.18695326168457885
# Run # 288
# i: 4000 mc loss: 1.690e+06 data loss: 0.000e+00 loss: 1.690e+06 acceptance rate: 0.19720069982504373
# Run # 289
# i: 4000 mc loss: 1.689e+06 data loss: 0.000e+00 loss: 1.689e+06 acceptance rate: 0.20144963759060236
# Run # 290
# i: 4000 mc loss: 1.689e+06 data loss: 0.000e+00 loss: 1.689e+06 acceptance rate: 0.19495126218445388
# Run # 291
# i: 4000 mc loss: 1.689e+06 data loss: 0.000e+00 loss: 1.689e+06 acceptance rate: 0.19745063734066484
# Run # 292
# i: 4000 mc loss: 1.688e+06 data loss: 0.000e+00 loss: 1.688e+06 acceptance rate: 0.19645088727818044
# Run # 293
# i: 4000 mc loss: 1.688e+06 data loss: 0.000e+00 loss: 1.688e+06 acceptance rate: 0.20044988752811796
# Run # 294
# i: 4000 mc loss: 1.688e+06 data loss: 0.000e+00 loss: 1.688e+06 acceptance rate: 0.19320169957510622
# Run # 295
# i: 4000 mc loss: 1.687e+06 data loss: 0.000e+00 loss: 1.687e+06 acceptance rate: 0.20469882529367658
# Run # 296
# i: 4000 mc loss: 1.687e+06 data loss: 0.000e+00 loss: 1.687e+06 acceptance rate: 0.20144963759060236
# Run # 297
# i: 4000 mc loss: 1.686e+06 data loss: 0.000e+00 loss: 1.686e+06 acceptance rate: 0.19745063734066484
# Run # 298
# i: 4000 mc loss: 1.686e+06 data loss: 0.000e+00 loss: 1.686e+06 acceptance rate: 0.20494876280929766
# Run # 299
# i: 4000 mc loss: 1.686e+06 data loss: 0.000e+00 loss: 1.686e+06 acceptance rate: 0.18895276180954762
# Run # 300
# i: 4000 mc loss: 1.685e+06 data loss: 0.000e+00 loss: 1.685e+06 acceptance rate: 0.19595101224693826
# Run # 301
# i: 4000 mc loss: 1.685e+06 data loss: 0.000e+00 loss: 1.685e+06 acceptance rate: 0.20544863784053988
# Run # 302
# i: 4000 mc loss: 1.684e+06 data loss: 0.000e+00 loss: 1.684e+06 acceptance rate: 0.19570107473131718
# Run # 303
# i: 4000 mc loss: 1.684e+06 data loss: 0.000e+00 loss: 1.684e+06 acceptance rate: 0.2041989502624344
# Run # 304
# i: 4000 mc loss: 1.684e+06 data loss: 0.000e+00 loss: 1.684e+06 acceptance rate: 0.19270182454386403
# Run # 305
# i: 4000 mc loss: 1.683e+06 data loss: 0.000e+00 loss: 1.683e+06 acceptance rate: 0.20619845038740314
# Run # 306
# i: 4000 mc loss: 1.683e+06 data loss: 0.000e+00 loss: 1.683e+06 acceptance rate: 0.18645338665333666
# Run # 307
# i: 4000 mc loss: 1.683e+06 data loss: 0.000e+00 loss: 1.683e+06 acceptance rate: 0.184703824043989
# Run # 308
# i: 4000 mc loss: 1.682e+06 data loss: 0.000e+00 loss: 1.682e+06 acceptance rate: 0.1942014496375906
# Run # 309
# i: 4000 mc loss: 1.682e+06 data loss: 0.000e+00 loss: 1.682e+06 acceptance rate: 0.19570107473131718
# Run # 310
# i: 4000 mc loss: 1.682e+06 data loss: 0.000e+00 loss: 1.682e+06 acceptance rate: 0.1944513871532117
# Run # 311
# i: 4000 mc loss: 1.681e+06 data loss: 0.000e+00 loss: 1.681e+06 acceptance rate: 0.18770307423144214
# Run # 312
# i: 4000 mc loss: 1.681e+06 data loss: 0.000e+00 loss: 1.681e+06 acceptance rate: 0.19720069982504373
# Run # 313
# i: 4000 mc loss: 1.680e+06 data loss: 0.000e+00 loss: 1.680e+06 acceptance rate: 0.1942014496375906
# Run # 314
# i: 4000 mc loss: 1.680e+06 data loss: 0.000e+00 loss: 1.680e+06 acceptance rate: 0.1939515121219695
# Run # 315
# i: 4000 mc loss: 1.680e+06 data loss: 0.000e+00 loss: 1.680e+06 acceptance rate: 0.20169957510622344
# Run # 316
# i: 4000 mc loss: 1.680e+06 data loss: 0.000e+00 loss: 1.680e+06 acceptance rate: 0.20694826293426644
# Run # 317
# i: 4000 mc loss: 1.679e+06 data loss: 0.000e+00 loss: 1.679e+06 acceptance rate: 0.20894776305923518
# Run # 318
# i: 4000 mc loss: 1.679e+06 data loss: 0.000e+00 loss: 1.679e+06 acceptance rate: 0.20544863784053988
# Run # 319
# i: 4000 mc loss: 1.678e+06 data loss: 0.000e+00 loss: 1.678e+06 acceptance rate: 0.19070232441889529
# Run # 320
# i: 4000 mc loss: 1.678e+06 data loss: 0.000e+00 loss: 1.678e+06 acceptance rate: 0.1989502624343914
# Run # 321
# i: 4000 mc loss: 1.678e+06 data loss: 0.000e+00 loss: 1.678e+06 acceptance rate: 0.19570107473131718
# Run # 322
# i: 4000 mc loss: 1.677e+06 data loss: 0.000e+00 loss: 1.677e+06 acceptance rate: 0.195201199700075
# Run # 323
# i: 4000 mc loss: 1.677e+06 data loss: 0.000e+00 loss: 1.677e+06 acceptance rate: 0.20319920019995003
# Run # 324
# i: 4000 mc loss: 1.677e+06 data loss: 0.000e+00 loss: 1.677e+06 acceptance rate: 0.18720319920019995
# Run # 325
# i: 4000 mc loss: 1.676e+06 data loss: 0.000e+00 loss: 1.676e+06 acceptance rate: 0.19545113721569607
# Run # 326
# i: 4000 mc loss: 1.676e+06 data loss: 0.000e+00 loss: 1.676e+06 acceptance rate: 0.20044988752811796
# Run # 327
# i: 4000 mc loss: 1.676e+06 data loss: 0.000e+00 loss: 1.676e+06 acceptance rate: 0.1989502624343914
# Run # 328
# i: 4000 mc loss: 1.675e+06 data loss: 0.000e+00 loss: 1.675e+06 acceptance rate: 0.1947013246688328
# Run # 329
# i: 4000 mc loss: 1.675e+06 data loss: 0.000e+00 loss: 1.675e+06 acceptance rate: 0.1989502624343914
# Run # 330
# i: 4000 mc loss: 1.675e+06 data loss: 0.000e+00 loss: 1.675e+06 acceptance rate: 0.1887028242939265
# Run # 331
# i: 4000 mc loss: 1.674e+06 data loss: 0.000e+00 loss: 1.674e+06 acceptance rate: 0.20044988752811796
# Run # 332
# i: 4000 mc loss: 1.674e+06 data loss: 0.000e+00 loss: 1.674e+06 acceptance rate: 0.19670082479380155
# Run # 333
# i: 4000 mc loss: 1.674e+06 data loss: 0.000e+00 loss: 1.674e+06 acceptance rate: 0.20169957510622344
# Run # 334
# i: 4000 mc loss: 1.673e+06 data loss: 0.000e+00 loss: 1.673e+06 acceptance rate: 0.19770057485628592
# Run # 335
# i: 4000 mc loss: 1.673e+06 data loss: 0.000e+00 loss: 1.673e+06 acceptance rate: 0.19245188702824295
# Run # 336
# i: 4000 mc loss: 1.673e+06 data loss: 0.000e+00 loss: 1.673e+06 acceptance rate: 0.18745313671582103
# Run # 337
# i: 4000 mc loss: 1.672e+06 data loss: 0.000e+00 loss: 1.672e+06 acceptance rate: 0.1947013246688328
# Run # 338
# i: 4000 mc loss: 1.672e+06 data loss: 0.000e+00 loss: 1.672e+06 acceptance rate: 0.20319920019995003
# Run # 339
# i: 4000 mc loss: 1.672e+06 data loss: 0.000e+00 loss: 1.672e+06 acceptance rate: 0.20744813796550862
# Run # 340
# i: 4000 mc loss: 1.671e+06 data loss: 0.000e+00 loss: 1.671e+06 acceptance rate: 0.195201199700075
# Run # 341
# i: 4000 mc loss: 1.671e+06 data loss: 0.000e+00 loss: 1.671e+06 acceptance rate: 0.2041989502624344
# Run # 342
# i: 4000 mc loss: 1.671e+06 data loss: 0.000e+00 loss: 1.671e+06 acceptance rate: 0.2041989502624344
# Run # 343
# i: 4000 mc loss: 1.671e+06 data loss: 0.000e+00 loss: 1.671e+06 acceptance rate: 0.2026993251687078
# Run # 344
# i: 4000 mc loss: 1.670e+06 data loss: 0.000e+00 loss: 1.670e+06 acceptance rate: 0.20044988752811796
# Run # 345
# i: 4000 mc loss: 1.670e+06 data loss: 0.000e+00 loss: 1.670e+06 acceptance rate: 0.1892026993251687
# Run # 346
# i: 4000 mc loss: 1.670e+06 data loss: 0.000e+00 loss: 1.670e+06 acceptance rate: 0.21469632591852036
# Run # 347
# i: 4000 mc loss: 1.669e+06 data loss: 0.000e+00 loss: 1.669e+06 acceptance rate: 0.1887028242939265
# Run # 348
# i: 4000 mc loss: 1.669e+06 data loss: 0.000e+00 loss: 1.669e+06 acceptance rate: 0.20194951262184455
# Run # 349
# i: 4000 mc loss: 1.669e+06 data loss: 0.000e+00 loss: 1.669e+06 acceptance rate: 0.1894526368407898
# Run # 350
# i: 4000 mc loss: 1.668e+06 data loss: 0.000e+00 loss: 1.668e+06 acceptance rate: 0.19495126218445388
# Run # 351
# i: 4000 mc loss: 1.668e+06 data loss: 0.000e+00 loss: 1.668e+06 acceptance rate: 0.19245188702824295
# Run # 352
# i: 4000 mc loss: 1.668e+06 data loss: 0.000e+00 loss: 1.668e+06 acceptance rate: 0.20119970007498125
# Run # 353
# i: 4000 mc loss: 1.667e+06 data loss: 0.000e+00 loss: 1.667e+06 acceptance rate: 0.20019995001249688
# Run # 354
# i: 4000 mc loss: 1.667e+06 data loss: 0.000e+00 loss: 1.667e+06 acceptance rate: 0.19270182454386403
# Run # 355
# i: 4000 mc loss: 1.667e+06 data loss: 0.000e+00 loss: 1.667e+06 acceptance rate: 0.1947013246688328
# Run # 356
# i: 4000 mc loss: 1.666e+06 data loss: 0.000e+00 loss: 1.666e+06 acceptance rate: 0.1854536365908523
# Run # 357
# i: 4000 mc loss: 1.666e+06 data loss: 0.000e+00 loss: 1.666e+06 acceptance rate: 0.20944763809047737
# Run # 358
# i: 4000 mc loss: 1.666e+06 data loss: 0.000e+00 loss: 1.666e+06 acceptance rate: 0.19745063734066484
# Run # 359
# i: 4000 mc loss: 1.665e+06 data loss: 0.000e+00 loss: 1.665e+06 acceptance rate: 0.20544863784053988
# Run # 360
# i: 4000 mc loss: 1.665e+06 data loss: 0.000e+00 loss: 1.665e+06 acceptance rate: 0.189952511872032
# Run # 361
# i: 4000 mc loss: 1.665e+06 data loss: 0.000e+00 loss: 1.665e+06 acceptance rate: 0.20644838790302425
# Run # 362
# i: 4000 mc loss: 1.664e+06 data loss: 0.000e+00 loss: 1.664e+06 acceptance rate: 0.19495126218445388
# Run # 363
# i: 4000 mc loss: 1.664e+06 data loss: 0.000e+00 loss: 1.664e+06 acceptance rate: 0.20569857535616096
# Run # 364
# i: 4000 mc loss: 1.664e+06 data loss: 0.000e+00 loss: 1.664e+06 acceptance rate: 0.20469882529367658
# Run # 365
# i: 4000 mc loss: 1.663e+06 data loss: 0.000e+00 loss: 1.663e+06 acceptance rate: 0.19270182454386403
# Run # 366
# i: 4000 mc loss: 1.663e+06 data loss: 0.000e+00 loss: 1.663e+06 acceptance rate: 0.20469882529367658
# Run # 367
# i: 4000 mc loss: 1.663e+06 data loss: 0.000e+00 loss: 1.663e+06 acceptance rate: 0.1987003249187703
# Run # 368
# i: 4000 mc loss: 1.662e+06 data loss: 0.000e+00 loss: 1.662e+06 acceptance rate: 0.19695076230942266
# Run # 369
# i: 4000 mc loss: 1.662e+06 data loss: 0.000e+00 loss: 1.662e+06 acceptance rate: 0.19545113721569607
# Run # 370
# i: 4000 mc loss: 1.662e+06 data loss: 0.000e+00 loss: 1.662e+06 acceptance rate: 0.19595101224693826
# Run # 371
# i: 4000 mc loss: 1.662e+06 data loss: 0.000e+00 loss: 1.662e+06 acceptance rate: 0.20119970007498125
# Run # 372
# i: 4000 mc loss: 1.661e+06 data loss: 0.000e+00 loss: 1.661e+06 acceptance rate: 0.19570107473131718
# Run # 373
# i: 4000 mc loss: 1.661e+06 data loss: 0.000e+00 loss: 1.661e+06 acceptance rate: 0.1942014496375906
# Run # 374
# i: 4000 mc loss: 1.661e+06 data loss: 0.000e+00 loss: 1.661e+06 acceptance rate: 0.19670082479380155
# Run # 375
# i: 4000 mc loss: 1.660e+06 data loss: 0.000e+00 loss: 1.660e+06 acceptance rate: 0.1892026993251687
# Run # 376
# i: 4000 mc loss: 1.660e+06 data loss: 0.000e+00 loss: 1.660e+06 acceptance rate: 0.19045238690327418
# Run # 377
# i: 4000 mc loss: 1.660e+06 data loss: 0.000e+00 loss: 1.660e+06 acceptance rate: 0.20244938765308673
# Run # 378
# i: 4000 mc loss: 1.660e+06 data loss: 0.000e+00 loss: 1.660e+06 acceptance rate: 0.2026993251687078
# Run # 379
# i: 4000 mc loss: 1.659e+06 data loss: 0.000e+00 loss: 1.659e+06 acceptance rate: 0.18745313671582103
# Run # 380
# i: 4000 mc loss: 1.659e+06 data loss: 0.000e+00 loss: 1.659e+06 acceptance rate: 0.1997000749812547
# Run # 381
# i: 4000 mc loss: 1.659e+06 data loss: 0.000e+00 loss: 1.659e+06 acceptance rate: 0.19545113721569607
# Run # 382
# i: 4000 mc loss: 1.659e+06 data loss: 0.000e+00 loss: 1.659e+06 acceptance rate: 0.1849537615596101
# Run # 383
# i: 4000 mc loss: 1.658e+06 data loss: 0.000e+00 loss: 1.658e+06 acceptance rate: 0.20194951262184455
# Run # 384
# i: 4000 mc loss: 1.658e+06 data loss: 0.000e+00 loss: 1.658e+06 acceptance rate: 0.1989502624343914
# Run # 385
# i: 4000 mc loss: 1.658e+06 data loss: 0.000e+00 loss: 1.658e+06 acceptance rate: 0.19245188702824295
# Run # 386
# i: 4000 mc loss: 1.658e+06 data loss: 0.000e+00 loss: 1.658e+06 acceptance rate: 0.19095226193451637
# Run # 387
# i: 4000 mc loss: 1.658e+06 data loss: 0.000e+00 loss: 1.658e+06 acceptance rate: 0.1802049487628093
# Run # 388
# i: 4000 mc loss: 1.657e+06 data loss: 0.000e+00 loss: 1.657e+06 acceptance rate: 0.189952511872032
# Run # 389
# i: 4000 mc loss: 1.657e+06 data loss: 0.000e+00 loss: 1.657e+06 acceptance rate: 0.19220194951262184
# Run # 390
# i: 4000 mc loss: 1.657e+06 data loss: 0.000e+00 loss: 1.657e+06 acceptance rate: 0.19670082479380155
# Run # 391
# i: 4000 mc loss: 1.657e+06 data loss: 0.000e+00 loss: 1.657e+06 acceptance rate: 0.20744813796550862
# Run # 392
# i: 4000 mc loss: 1.656e+06 data loss: 0.000e+00 loss: 1.656e+06 acceptance rate: 0.19095226193451637
# Run # 393
# i: 4000 mc loss: 1.656e+06 data loss: 0.000e+00 loss: 1.656e+06 acceptance rate: 0.19320169957510622
# Run # 394
# i: 4000 mc loss: 1.656e+06 data loss: 0.000e+00 loss: 1.656e+06 acceptance rate: 0.20069982504373907
# Run # 395
# i: 4000 mc loss: 1.655e+06 data loss: 0.000e+00 loss: 1.655e+06 acceptance rate: 0.19745063734066484
# Run # 396
# i: 4000 mc loss: 1.655e+06 data loss: 0.000e+00 loss: 1.655e+06 acceptance rate: 0.20244938765308673
# Run # 397
# i: 4000 mc loss: 1.655e+06 data loss: 0.000e+00 loss: 1.655e+06 acceptance rate: 0.20144963759060236
# Run # 398
# i: 4000 mc loss: 1.655e+06 data loss: 0.000e+00 loss: 1.655e+06 acceptance rate: 0.1947013246688328
# Run # 399
# i: 4000 mc loss: 1.654e+06 data loss: 0.000e+00 loss: 1.654e+06 acceptance rate: 0.18370407398150462
# Run # 400
# i: 4000 mc loss: 1.654e+06 data loss: 0.000e+00 loss: 1.654e+06 acceptance rate: 0.19270182454386403
# Run # 401
# i: 4000 mc loss: 1.654e+06 data loss: 0.000e+00 loss: 1.654e+06 acceptance rate: 0.20019995001249688
# Run # 402
# i: 4000 mc loss: 1.654e+06 data loss: 0.000e+00 loss: 1.654e+06 acceptance rate: 0.1802049487628093
# Run # 403
# i: 4000 mc loss: 1.653e+06 data loss: 0.000e+00 loss: 1.653e+06 acceptance rate: 0.20069982504373907
# Run # 404
# i: 4000 mc loss: 1.653e+06 data loss: 0.000e+00 loss: 1.653e+06 acceptance rate: 0.19745063734066484
# Run # 405
# i: 4000 mc loss: 1.653e+06 data loss: 0.000e+00 loss: 1.653e+06 acceptance rate: 0.19770057485628592
# Run # 406
# i: 4000 mc loss: 1.653e+06 data loss: 0.000e+00 loss: 1.653e+06 acceptance rate: 0.2026993251687078
# Run # 407
# i: 4000 mc loss: 1.652e+06 data loss: 0.000e+00 loss: 1.652e+06 acceptance rate: 0.18570357410647337
# Run # 408
# i: 4000 mc loss: 1.652e+06 data loss: 0.000e+00 loss: 1.652e+06 acceptance rate: 0.20044988752811796
# Run # 409
# i: 4000 mc loss: 1.652e+06 data loss: 0.000e+00 loss: 1.652e+06 acceptance rate: 0.17370657335666084
# Run # 410
# i: 4000 mc loss: 1.651e+06 data loss: 0.000e+00 loss: 1.651e+06 acceptance rate: 0.20194951262184455
# Run # 411
# i: 4000 mc loss: 1.651e+06 data loss: 0.000e+00 loss: 1.651e+06 acceptance rate: 0.20544863784053988
# Run # 412
# i: 4000 mc loss: 1.651e+06 data loss: 0.000e+00 loss: 1.651e+06 acceptance rate: 0.19270182454386403
# Run # 413
# i: 4000 mc loss: 1.651e+06 data loss: 0.000e+00 loss: 1.651e+06 acceptance rate: 0.19245188702824295
# Run # 414
# i: 4000 mc loss: 1.651e+06 data loss: 0.000e+00 loss: 1.651e+06 acceptance rate: 0.21169707573106725
# Run # 415
# i: 4000 mc loss: 1.650e+06 data loss: 0.000e+00 loss: 1.650e+06 acceptance rate: 0.20119970007498125
# Run # 416
# i: 4000 mc loss: 1.650e+06 data loss: 0.000e+00 loss: 1.650e+06 acceptance rate: 0.1937015746063484
# Run # 417
# i: 4000 mc loss: 1.650e+06 data loss: 0.000e+00 loss: 1.650e+06 acceptance rate: 0.1939515121219695
# Run # 418
# i: 4000 mc loss: 1.649e+06 data loss: 0.000e+00 loss: 1.649e+06 acceptance rate: 0.19620094976255936
# Run # 419
# i: 4000 mc loss: 1.649e+06 data loss: 0.000e+00 loss: 1.649e+06 acceptance rate: 0.19595101224693826
# Run # 420
# i: 4000 mc loss: 1.649e+06 data loss: 0.000e+00 loss: 1.649e+06 acceptance rate: 0.1887028242939265
# Run # 421
# i: 4000 mc loss: 1.649e+06 data loss: 0.000e+00 loss: 1.649e+06 acceptance rate: 0.19320169957510622
# Run # 422
# i: 4000 mc loss: 1.649e+06 data loss: 0.000e+00 loss: 1.649e+06 acceptance rate: 0.18770307423144214
# Run # 423
# i: 4000 mc loss: 1.648e+06 data loss: 0.000e+00 loss: 1.648e+06 acceptance rate: 0.1937015746063484
# Run # 424
# i: 4000 mc loss: 1.648e+06 data loss: 0.000e+00 loss: 1.648e+06 acceptance rate: 0.1942014496375906
# Run # 425
# i: 4000 mc loss: 1.648e+06 data loss: 0.000e+00 loss: 1.648e+06 acceptance rate: 0.19545113721569607
# Run # 426
# i: 4000 mc loss: 1.648e+06 data loss: 0.000e+00 loss: 1.648e+06 acceptance rate: 0.1982004498875281
# Run # 427
# i: 4000 mc loss: 1.647e+06 data loss: 0.000e+00 loss: 1.647e+06 acceptance rate: 0.19545113721569607
# Run # 428
# i: 4000 mc loss: 1.647e+06 data loss: 0.000e+00 loss: 1.647e+06 acceptance rate: 0.19245188702824295
# Run # 429
# i: 4000 mc loss: 1.647e+06 data loss: 0.000e+00 loss: 1.647e+06 acceptance rate: 0.189952511872032
# Run # 430
# i: 4000 mc loss: 1.647e+06 data loss: 0.000e+00 loss: 1.647e+06 acceptance rate: 0.1892026993251687
# Run # 431
# i: 4000 mc loss: 1.647e+06 data loss: 0.000e+00 loss: 1.647e+06 acceptance rate: 0.18520369907523118
# Run # 432
# i: 4000 mc loss: 1.646e+06 data loss: 0.000e+00 loss: 1.646e+06 acceptance rate: 0.17670582354411396
# Run # 433
# i: 4000 mc loss: 1.646e+06 data loss: 0.000e+00 loss: 1.646e+06 acceptance rate: 0.18395401149712573
# Run # 434
# i: 4000 mc loss: 1.646e+06 data loss: 0.000e+00 loss: 1.646e+06 acceptance rate: 0.21119720069982503
# Run # 435
# i: 4000 mc loss: 1.646e+06 data loss: 0.000e+00 loss: 1.646e+06 acceptance rate: 0.189952511872032
# Run # 436
# i: 4000 mc loss: 1.645e+06 data loss: 0.000e+00 loss: 1.645e+06 acceptance rate: 0.19170207448137966
# Run # 437
# i: 4000 mc loss: 1.645e+06 data loss: 0.000e+00 loss: 1.645e+06 acceptance rate: 0.18795301174706325
# Run # 438
# i: 4000 mc loss: 1.645e+06 data loss: 0.000e+00 loss: 1.645e+06 acceptance rate: 0.19570107473131718
# Run # 439
# i: 4000 mc loss: 1.645e+06 data loss: 0.000e+00 loss: 1.645e+06 acceptance rate: 0.189952511872032
# Run # 440
# i: 4000 mc loss: 1.645e+06 data loss: 0.000e+00 loss: 1.645e+06 acceptance rate: 0.19345163709072732
# Run # 441
# i: 4000 mc loss: 1.644e+06 data loss: 0.000e+00 loss: 1.644e+06 acceptance rate: 0.18445388652836792
# Run # 442
# i: 4000 mc loss: 1.644e+06 data loss: 0.000e+00 loss: 1.644e+06 acceptance rate: 0.19220194951262184
# Run # 443
# i: 4000 mc loss: 1.644e+06 data loss: 0.000e+00 loss: 1.644e+06 acceptance rate: 0.1987003249187703
# Run # 444
# i: 4000 mc loss: 1.644e+06 data loss: 0.000e+00 loss: 1.644e+06 acceptance rate: 0.20294926268432892
# Run # 445
# i: 4000 mc loss: 1.644e+06 data loss: 0.000e+00 loss: 1.644e+06 acceptance rate: 0.20144963759060236
# Run # 446
# i: 4000 mc loss: 1.643e+06 data loss: 0.000e+00 loss: 1.643e+06 acceptance rate: 0.20294926268432892
# Run # 447
# i: 4000 mc loss: 1.643e+06 data loss: 0.000e+00 loss: 1.643e+06 acceptance rate: 0.1994501374656336
# Run # 448
# i: 4000 mc loss: 1.643e+06 data loss: 0.000e+00 loss: 1.643e+06 acceptance rate: 0.19270182454386403
# Run # 449
# i: 4000 mc loss: 1.643e+06 data loss: 0.000e+00 loss: 1.643e+06 acceptance rate: 0.17295676080979755
# Run # 450
# i: 4000 mc loss: 1.642e+06 data loss: 0.000e+00 loss: 1.642e+06 acceptance rate: 0.19545113721569607
# Run # 451
# i: 4000 mc loss: 1.642e+06 data loss: 0.000e+00 loss: 1.642e+06 acceptance rate: 0.18395401149712573
# Run # 452
# i: 4000 mc loss: 1.642e+06 data loss: 0.000e+00 loss: 1.642e+06 acceptance rate: 0.19495126218445388
# Run # 453
# i: 4000 mc loss: 1.642e+06 data loss: 0.000e+00 loss: 1.642e+06 acceptance rate: 0.18520369907523118
# Run # 454
# i: 4000 mc loss: 1.641e+06 data loss: 0.000e+00 loss: 1.641e+06 acceptance rate: 0.19045238690327418
# Run # 455
# i: 4000 mc loss: 1.641e+06 data loss: 0.000e+00 loss: 1.641e+06 acceptance rate: 0.1939515121219695
# Run # 456
# i: 4000 mc loss: 1.641e+06 data loss: 0.000e+00 loss: 1.641e+06 acceptance rate: 0.208447888027993
# Run # 457
# i: 4000 mc loss: 1.641e+06 data loss: 0.000e+00 loss: 1.641e+06 acceptance rate: 0.19195201199700074
# Run # 458
# i: 4000 mc loss: 1.640e+06 data loss: 0.000e+00 loss: 1.640e+06 acceptance rate: 0.20444888777805548
# Run # 459
# i: 4000 mc loss: 1.640e+06 data loss: 0.000e+00 loss: 1.640e+06 acceptance rate: 0.19670082479380155
# Run # 460
# i: 4000 mc loss: 1.640e+06 data loss: 0.000e+00 loss: 1.640e+06 acceptance rate: 0.20544863784053988
# Run # 461
# i: 4000 mc loss: 1.640e+06 data loss: 0.000e+00 loss: 1.640e+06 acceptance rate: 0.19670082479380155
# Run # 462
# i: 4000 mc loss: 1.640e+06 data loss: 0.000e+00 loss: 1.640e+06 acceptance rate: 0.19195201199700074
# Run # 463
# i: 4000 mc loss: 1.639e+06 data loss: 0.000e+00 loss: 1.639e+06 acceptance rate: 0.19745063734066484
# Run # 464
# i: 4000 mc loss: 1.639e+06 data loss: 0.000e+00 loss: 1.639e+06 acceptance rate: 0.19245188702824295
# Run # 465
# i: 4000 mc loss: 1.639e+06 data loss: 0.000e+00 loss: 1.639e+06 acceptance rate: 0.1989502624343914
# Run # 466
# i: 4000 mc loss: 1.639e+06 data loss: 0.000e+00 loss: 1.639e+06 acceptance rate: 0.18645338665333666
# Run # 467
# i: 4000 mc loss: 1.638e+06 data loss: 0.000e+00 loss: 1.638e+06 acceptance rate: 0.19120219945013747
# Run # 468
# i: 4000 mc loss: 1.638e+06 data loss: 0.000e+00 loss: 1.638e+06 acceptance rate: 0.20119970007498125
# Run # 469
# i: 4000 mc loss: 1.638e+06 data loss: 0.000e+00 loss: 1.638e+06 acceptance rate: 0.1989502624343914
# Run # 470
# i: 4000 mc loss: 1.638e+06 data loss: 0.000e+00 loss: 1.638e+06 acceptance rate: 0.18770307423144214
# Run # 471
# i: 4000 mc loss: 1.638e+06 data loss: 0.000e+00 loss: 1.638e+06 acceptance rate: 0.19295176205948514
# Run # 472
# i: 4000 mc loss: 1.637e+06 data loss: 0.000e+00 loss: 1.637e+06 acceptance rate: 0.20294926268432892
# Run # 473
# i: 4000 mc loss: 1.637e+06 data loss: 0.000e+00 loss: 1.637e+06 acceptance rate: 0.1902024493876531
# Run # 474
# i: 4000 mc loss: 1.637e+06 data loss: 0.000e+00 loss: 1.637e+06 acceptance rate: 0.19295176205948514
# Run # 475
# i: 4000 mc loss: 1.637e+06 data loss: 0.000e+00 loss: 1.637e+06 acceptance rate: 0.18770307423144214
# Run # 476
# i: 4000 mc loss: 1.637e+06 data loss: 0.000e+00 loss: 1.637e+06 acceptance rate: 0.1947013246688328
# Run # 477
# i: 4000 mc loss: 1.636e+06 data loss: 0.000e+00 loss: 1.636e+06 acceptance rate: 0.20319920019995003
# Run # 478
# i: 4000 mc loss: 1.636e+06 data loss: 0.000e+00 loss: 1.636e+06 acceptance rate: 0.17945513621594603
# Run # 479
# i: 4000 mc loss: 1.636e+06 data loss: 0.000e+00 loss: 1.636e+06 acceptance rate: 0.1902024493876531
# Run # 480
# i: 4000 mc loss: 1.636e+06 data loss: 0.000e+00 loss: 1.636e+06 acceptance rate: 0.18745313671582103
# Run # 481
# i: 4000 mc loss: 1.636e+06 data loss: 0.000e+00 loss: 1.636e+06 acceptance rate: 0.18270432391902025
# Run # 482
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.19570107473131718
# Run # 483
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.20094976255936017
# Run # 484
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.19645088727818044
# Run # 485
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.18620344913771558
# Run # 486
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.20069982504373907
# Run # 487
# i: 4000 mc loss: 1.635e+06 data loss: 0.000e+00 loss: 1.635e+06 acceptance rate: 0.195201199700075
# Run # 488
# i: 4000 mc loss: 1.634e+06 data loss: 0.000e+00 loss: 1.634e+06 acceptance rate: 0.20719820044988752
# Run # 489
# i: 4000 mc loss: 1.634e+06 data loss: 0.000e+00 loss: 1.634e+06 acceptance rate: 0.20619845038740314
# Run # 490
# i: 4000 mc loss: 1.634e+06 data loss: 0.000e+00 loss: 1.634e+06 acceptance rate: 0.19070232441889529
# Run # 491
# i: 4000 mc loss: 1.634e+06 data loss: 0.000e+00 loss: 1.634e+06 acceptance rate: 0.1992001999500125
# Run # 492
# i: 4000 mc loss: 1.634e+06 data loss: 0.000e+00 loss: 1.634e+06 acceptance rate: 0.18720319920019995
# Run # 493
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.18570357410647337
# Run # 494
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.19270182454386403
# Run # 495
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.1894526368407898
# Run # 496
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.19570107473131718
# Run # 497
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.19045238690327418
# Run # 498
# i: 4000 mc loss: 1.633e+06 data loss: 0.000e+00 loss: 1.633e+06 acceptance rate: 0.184703824043989
# Run # 499
# i: 4000 mc loss: 1.632e+06 data loss: 0.000e+00 loss: 1.632e+06 acceptance rate: 0.19695076230942266
# Run # 500
# i: 4000 mc loss: 1.632e+06 data loss: 0.000e+00 loss: 1.632e+06 acceptance rate: 0.18970257435641089
# Run # 501
# i: 4000 mc loss: 1.632e+06 data loss: 0.000e+00 loss: 1.632e+06 acceptance rate: 0.1939515121219695
# Run # 502
# i: 4000 mc loss: 1.632e+06 data loss: 0.000e+00 loss: 1.632e+06 acceptance rate: 0.19195201199700074
# Run # 503
# i: 4000 mc loss: 1.632e+06 data loss: 0.000e+00 loss: 1.632e+06 acceptance rate: 0.19070232441889529
# Run # 504
# i: 4000 mc loss: 1.631e+06 data loss: 0.000e+00 loss: 1.631e+06 acceptance rate: 0.19995001249687577
# Run # 505
# i: 4000 mc loss: 1.631e+06 data loss: 0.000e+00 loss: 1.631e+06 acceptance rate: 0.19195201199700074
# Run # 506
# i: 4000 mc loss: 1.631e+06 data loss: 0.000e+00 loss: 1.631e+06 acceptance rate: 0.18520369907523118
# Run # 507
# i: 4000 mc loss: 1.631e+06 data loss: 0.000e+00 loss: 1.631e+06 acceptance rate: 0.18445388652836792
# Run # 508
# i: 4000 mc loss: 1.631e+06 data loss: 0.000e+00 loss: 1.631e+06 acceptance rate: 0.20219945013746563
# Run # 509
# i: 4000 mc loss: 1.630e+06 data loss: 0.000e+00 loss: 1.630e+06 acceptance rate: 0.18620344913771558
# Run # 510
# i: 4000 mc loss: 1.630e+06 data loss: 0.000e+00 loss: 1.630e+06 acceptance rate: 0.1939515121219695
# Run # 511
# i: 4000 mc loss: 1.630e+06 data loss: 0.000e+00 loss: 1.630e+06 acceptance rate: 0.1887028242939265
# Run # 512
# i: 4000 mc loss: 1.630e+06 data loss: 0.000e+00 loss: 1.630e+06 acceptance rate: 0.18345413646588352
# Run # 513
# i: 4000 mc loss: 1.630e+06 data loss: 0.000e+00 loss: 1.630e+06 acceptance rate: 0.18695326168457885
# Run # 514
# i: 4000 mc loss: 1.629e+06 data loss: 0.000e+00 loss: 1.629e+06 acceptance rate: 0.20044988752811796
# Run # 515
# i: 4000 mc loss: 1.629e+06 data loss: 0.000e+00 loss: 1.629e+06 acceptance rate: 0.18795301174706325
# Run # 516
# i: 4000 mc loss: 1.629e+06 data loss: 0.000e+00 loss: 1.629e+06 acceptance rate: 0.19070232441889529
# Run # 517
# i: 4000 mc loss: 1.629e+06 data loss: 0.000e+00 loss: 1.629e+06 acceptance rate: 0.18245438640339914
# Run # 518
# i: 4000 mc loss: 1.629e+06 data loss: 0.000e+00 loss: 1.629e+06 acceptance rate: 0.19745063734066484
# Run # 519
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.20169957510622344
# Run # 520
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.18620344913771558
# Run # 521
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.19070232441889529
# Run # 522
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.18795301174706325
# Run # 523
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.21344663834041488
# Run # 524
# i: 4000 mc loss: 1.628e+06 data loss: 0.000e+00 loss: 1.628e+06 acceptance rate: 0.18770307423144214
# Run # 525
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.1894526368407898
# Run # 526
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.18795301174706325
# Run # 527
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.19145213696575855
# Run # 528
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.1842039490127468
# Run # 529
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.18645338665333666
# Run # 530
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.18695326168457885
# Run # 531
# i: 4000 mc loss: 1.627e+06 data loss: 0.000e+00 loss: 1.627e+06 acceptance rate: 0.19845038740314921
# Run # 532
# i: 4000 mc loss: 1.626e+06 data loss: 0.000e+00 loss: 1.626e+06 acceptance rate: 0.18295426143464133
# Run # 533
# i: 4000 mc loss: 1.626e+06 data loss: 0.000e+00 loss: 1.626e+06 acceptance rate: 0.19670082479380155
# Run # 534
# i: 4000 mc loss: 1.626e+06 data loss: 0.000e+00 loss: 1.626e+06 acceptance rate: 0.19270182454386403
# Run # 535
# i: 4000 mc loss: 1.626e+06 data loss: 0.000e+00 loss: 1.626e+06 acceptance rate: 0.19345163709072732
# Run # 536
# i: 4000 mc loss: 1.626e+06 data loss: 0.000e+00 loss: 1.626e+06 acceptance rate: 0.1789552611847038
# Run # 537
# i: 4000 mc loss: 1.625e+06 data loss: 0.000e+00 loss: 1.625e+06 acceptance rate: 0.17720569857535617
# Run # 538
# i: 4000 mc loss: 1.625e+06 data loss: 0.000e+00 loss: 1.625e+06 acceptance rate: 0.19595101224693826
# Run # 539
# i: 4000 mc loss: 1.625e+06 data loss: 0.000e+00 loss: 1.625e+06 acceptance rate: 0.18570357410647337
# Run # 540
# i: 4000 mc loss: 1.625e+06 data loss: 0.000e+00 loss: 1.625e+06 acceptance rate: 0.18745313671582103
# Run # 541
# i: 4000 mc loss: 1.625e+06 data loss: 0.000e+00 loss: 1.625e+06 acceptance rate: 0.1942014496375906
# Run # 542
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.18320419895026244
# Run # 543
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.1802049487628093
# Run # 544
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.1947013246688328
# Run # 545
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.18720319920019995
# Run # 546
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.18745313671582103
# Run # 547
# i: 4000 mc loss: 1.624e+06 data loss: 0.000e+00 loss: 1.624e+06 acceptance rate: 0.18745313671582103
# Run # 548
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.20469882529367658
# Run # 549
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.1937015746063484
# Run # 550
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.19095226193451637
# Run # 551
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.18295426143464133
# Run # 552
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.19170207448137966
# Run # 553
# i: 4000 mc loss: 1.623e+06 data loss: 0.000e+00 loss: 1.623e+06 acceptance rate: 0.20044988752811796
# Run # 554
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.1997000749812547
# Run # 555
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.1942014496375906
# Run # 556
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.184703824043989
# Run # 557
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.19045238690327418
# Run # 558
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.18820294926268433
# Run # 559
# i: 4000 mc loss: 1.622e+06 data loss: 0.000e+00 loss: 1.622e+06 acceptance rate: 0.18720319920019995
# Run # 560
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.2041989502624344
# Run # 561
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.18845288677830543
# Run # 562
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.19595101224693826
# Run # 563
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.1992001999500125
# Run # 564
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.1987003249187703
# Run # 565
# i: 4000 mc loss: 1.621e+06 data loss: 0.000e+00 loss: 1.621e+06 acceptance rate: 0.1944513871532117
# Run # 566
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.20769807548112973
# Run # 567
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.20044988752811796
# Run # 568
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.18145463634091477
# Run # 569
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.19320169957510622
# Run # 570
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.18745313671582103
# Run # 571
# i: 4000 mc loss: 1.620e+06 data loss: 0.000e+00 loss: 1.620e+06 acceptance rate: 0.18820294926268433
# Run # 572
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.18720319920019995
# Run # 573
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.1892026993251687
# Run # 574
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.19120219945013747
# Run # 575
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.1842039490127468
# Run # 576
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.19070232441889529
# Run # 577
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.1942014496375906
# Run # 578
# i: 4000 mc loss: 1.619e+06 data loss: 0.000e+00 loss: 1.619e+06 acceptance rate: 0.18520369907523118
# Run # 579
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.1759560109972507
# Run # 580
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.19170207448137966
# Run # 581
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.18895276180954762
# Run # 582
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.19120219945013747
# Run # 583
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.17870532366908273
# Run # 584
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.18645338665333666
# Run # 585
# i: 4000 mc loss: 1.618e+06 data loss: 0.000e+00 loss: 1.618e+06 acceptance rate: 0.1942014496375906
# Run # 586
# i: 4000 mc loss: 1.617e+06 data loss: 0.000e+00 loss: 1.617e+06 acceptance rate: 0.18895276180954762
# Run # 587
# ...
# Run # 1258
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.18220444888777806
# Run # 1259
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.1894526368407898
# Run # 1260
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.1657085728567858
# Run # 1261
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.17345663584103974
# Run # 1262
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.18270432391902025
# Run # 1263
# i: 4000 mc loss: 1.557e+06 data loss: 0.000e+00 loss: 1.557e+06 acceptance rate: 0.18220444888777806
# Run # 1264
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18770307423144214
# Run # 1265
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18070482379405148
# Run # 1266
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.2039490127468133
# Run # 1267
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.1892026993251687
# Run # 1268
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.17495626093476632
# Run # 1269
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.17770557360659836
# Run # 1270
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18145463634091477
# Run # 1271
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18295426143464133
# Run # 1272
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.1992001999500125
# Run # 1273
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.19245188702824295
# Run # 1274
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.1804548862784304
# Run # 1275
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18595351162209448
# Run # 1276
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.1849537615596101
# Run # 1277
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18095476130967258
# Run # 1278
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.18645338665333666
# Run # 1279
# i: 4000 mc loss: 1.556e+06 data loss: 0.000e+00 loss: 1.556e+06 acceptance rate: 0.1892026993251687
# Run # 1280
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18595351162209448
# Run # 1281
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.1939515121219695
# Run # 1282
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18220444888777806
# Run # 1283
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18770307423144214
# Run # 1284
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18570357410647337
# Run # 1285
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.17395651087228192
# Run # 1286
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18445388652836792
# Run # 1287
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18270432391902025
# Run # 1288
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.17920519870032492
# Run # 1289
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.17920519870032492
# Run # 1290
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18820294926268433
# Run # 1291
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.1892026993251687
# Run # 1292
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18370407398150462
# Run # 1293
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.1939515121219695
# Run # 1294
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18295426143464133
# Run # 1295
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.18270432391902025
# Run # 1296
# i: 4000 mc loss: 1.555e+06 data loss: 0.000e+00 loss: 1.555e+06 acceptance rate: 0.17720569857535617
# Run # 1297
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.189952511872032
# Run # 1298
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.1887028242939265
# Run # 1299
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.17945513621594603
# Run # 1300
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.19795051237190703
# Run # 1301
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18595351162209448
# Run # 1302
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18145463634091477
# Run # 1303
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18820294926268433
# Run # 1304
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18520369907523118
# Run # 1305
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.1947013246688328
# Run # 1306
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18320419895026244
# Run # 1307
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18170457385653588
# Run # 1308
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18195451137215696
# Run # 1309
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18645338665333666
# Run # 1310
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.1939515121219695
# Run # 1311
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18520369907523118
# Run # 1312
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.1752061984503874
# Run # 1313
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.18245438640339914
# Run # 1314
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.1894526368407898
# Run # 1315
# i: 4000 mc loss: 1.554e+06 data loss: 0.000e+00 loss: 1.554e+06 acceptance rate: 0.19220194951262184
# Run # 1316
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.19220194951262184
# Run # 1317
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.20019995001249688
# Run # 1318
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.19295176205948514
# Run # 1319
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18295426143464133
# Run # 1320
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.1887028242939265
# Run # 1321
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.19320169957510622
# Run # 1322
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18970257435641089
# Run # 1323
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.19595101224693826
# Run # 1324
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18970257435641089
# Run # 1325
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.19545113721569607
# Run # 1326
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18320419895026244
# Run # 1327
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18245438640339914
# Run # 1328
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18070482379405148
# Run # 1329
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.1842039490127468
# Run # 1330
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18895276180954762
# Run # 1331
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.1802049487628093
# Run # 1332
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18370407398150462
# Run # 1333
# i: 4000 mc loss: 1.553e+06 data loss: 0.000e+00 loss: 1.553e+06 acceptance rate: 0.18770307423144214
# Run # 1334
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.19070232441889529
# Run # 1335
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.19270182454386403
# Run # 1336
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.18670332416895777
# Run # 1337
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.19120219945013747
# Run # 1338
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.17620594851287177
# Run # 1339
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.19320169957510622
# Run # 1340
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1854536365908523
# Run # 1341
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1887028242939265
# Run # 1342
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.18770307423144214
# Run # 1343
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1992001999500125
# Run # 1344
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1887028242939265
# Run # 1345
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.189952511872032
# Run # 1346
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.189952511872032
# Run # 1347
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.17620594851287177
# Run # 1348
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.19245188702824295
# Run # 1349
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.18445388652836792
# Run # 1350
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1842039490127468
# Run # 1351
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.1849537615596101
# Run # 1352
# i: 4000 mc loss: 1.552e+06 data loss: 0.000e+00 loss: 1.552e+06 acceptance rate: 0.18095476130967258
# Run # 1353
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18595351162209448
# Run # 1354
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18445388652836792
# Run # 1355
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.16520869782554362
# Run # 1356
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.1842039490127468
# Run # 1357
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18120469882529366
# Run # 1358
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18895276180954762
# Run # 1359
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18145463634091477
# Run # 1360
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.17195701074731318
# Run # 1361
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.19270182454386403
# Run # 1362
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18520369907523118
# Run # 1363
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.1894526368407898
# Run # 1364
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18370407398150462
# Run # 1365
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.1894526368407898
# Run # 1366
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18520369907523118
# Run # 1367
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.17870532366908273
# Run # 1368
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.18845288677830543
# Run # 1369
# i: 4000 mc loss: 1.551e+06 data loss: 0.000e+00 loss: 1.551e+06 acceptance rate: 0.1842039490127468
# Run # 1370
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.171457135716071
# Run # 1371
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.1942014496375906
# Run # 1372
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.1887028242939265
# Run # 1373
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.19670082479380155
# Run # 1374
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.18895276180954762
# Run # 1375
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.17945513621594603
# Run # 1376
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.18695326168457885
# Run # 1377
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.20519870032491877
# Run # 1378
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.18745313671582103
# Run # 1379
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.1887028242939265
# Run # 1380
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.19745063734066484
# Run # 1381
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.19195201199700074
# Run # 1382
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.17220694826293426
# Run # 1383
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.19220194951262184
# Run # 1384
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.18820294926268433
# Run # 1385
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.18970257435641089
# Run # 1386
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.189952511872032
# Run # 1387
# i: 4000 mc loss: 1.550e+06 data loss: 0.000e+00 loss: 1.550e+06 acceptance rate: 0.17220694826293426
# Run # 1388
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.1804548862784304
# Run # 1389
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.18395401149712573
# Run # 1390
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.18195451137215696
# Run # 1391
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.20244938765308673
# Run # 1392
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.19170207448137966
# Run # 1393
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.18670332416895777
# Run # 1394
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.18745313671582103
# Run # 1395
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.19220194951262184
# Run # 1396
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.18245438640339914
# Run # 1397
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.17945513621594603
# Run # 1398
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.1757060734816296
# Run # 1399
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.2086978255436141
# Run # 1400
# i: 4000 mc loss: 1.549e+06 data loss: 0.000e+00 loss: 1.549e+06 acceptance rate: 0.1802049487628093

# %%
plt.pcolormesh(xx, yy, np.loadtxt('./trial_2/beds/bed7000000.txt')) 
plt.axis('scaled')
plt.colorbar()

# %% [markdown]
# ### Verify Results

# %% [markdown]
# We can check several aspects of the results:
#
# - How the topography deviate from radar measurements
#
# - Mass flux residuals of the current topography
#
# - How loss reduce over time
#
# - Variogram of the simulated topography

# %%
plt.pcolormesh(xx,yy,beds[-1]-beds[0],cmap='RdBu')
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx,yy,beds[0],cmap='gist_earth')
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx,yy,beds[-1],cmap='gist_earth')
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx,yy,beds[-1] - cond_bed,cmap='gist_earth')
plt.title('difference between the last topography and the bed elevation measurements')
plt.axis('scaled')
plt.colorbar()

# %%
mass_flux_res = Topography.get_mass_conservation_residual(beds[-1],bedmap_surf,velx,vely,dhdt,smb,resolution)

plt.pcolormesh(xx,yy,mass_flux_res,cmap='RdBu',vmax=75,vmin=-75)
plt.title('mass flux residuals of the last iteration')
plt.axis('scaled')
plt.colorbar()

# %%
mc_res_bm = Topography.get_mass_conservation_residual(bedmachine_bed,bedmap_surf,velx,vely,dhdt,smb,resolution)

plt.pcolormesh(xx,yy,mc_res_bm,cmap='RdBu',vmax=75,vmin=-75)
plt.title('mass flux residuals of BedMachine')
plt.axis('scaled')
plt.colorbar()

# %%
loss_bedmachine = largeScaleChain.loss(mc_res_bm, bedmachine_bed - cond_bed)
loss_bedmachine

# %%
plt.plot(loss_mc,label='loss of the MCMC')
plt.axhline(loss_bedmachine[0],ls='--',c='red',label='loss of BedMachine')
plt.legend()

# %%
df['simulated_topography'] = sgs_bed.flatten()

# %%
# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
df_sampled = df.sample(frac=0.4, random_state=42)
df_sampled = df_sampled[df_sampled["simulated_topography"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
coords = df_sampled[['x','y']].values
#values = df_sampled['simulated_topography']
values = df_sampled['simulated_topography']

maxlag = 80000      # maximum range distance
n_lags = 30         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', 
                   n_lags=n_lags, maxlag=maxlag, normalize=False, 
                   model='matern', samples = 0.4)

# extract variogram values
xdata_sim = V1.bins
ydata_sim = V1.experimental
V1_p = V1.parameters

# %%
# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
df_sampled = df.sample(frac=0.4, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
coords = df_sampled[['x','y']].values
values = df_sampled['cond_bed']

maxlag = 80000      # maximum range distance
n_lags = 30         # num of bins (try decreasing if this is taking too long)

# compute variogram
V2 = skg.Variogram(coords, values, bin_func='even', 
                   n_lags=n_lags, maxlag=maxlag, normalize=False, 
                   model='matern', samples = 0.4)

# extract variogram values
xdata_cond = V2.bins
ydata_cond = V2.experimental
V2_p = V2.parameters

# %%
# compare experimental variogram
plt.figure(figsize=(6,4))
plt.scatter(xdata_sim, ydata_sim, s=12, c='b', label='variogram for simulated topography')
plt.scatter(xdata_cond, ydata_cond, s=12, c='g', label='variogram for radar measurements')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %% [markdown]
# ### Save Results
#
# Please remember to save the result for comparison later. For example, I always save the loss of every iteration, the acceptance rate (steps), and some topography.
#
# For example, you can save the topography every 1000 iteration:

# %%
beds.shape

# %%
for i in range(0,10000,1000):
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = largeScaleChain.run(n_iter=1000, RF=rf1)
    np.savetxt('loss_'+str(i)+'to'+str(i+1000), loss)
    np.savetxt('steps_'+str(i)+'to'+str(i+1000), steps) 
    np.savetxt('beds_at_' + str(i+1000) +'th_iteration',beds[-1])
    largeScaleChain.intial_bed =beds[-1]

# %% [markdown]
# Or you can save beds at more iterations. For the example, the code below save beds for every 100 iteration, while we are running the chain for 1000 iterations

# %%
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = largeScaleChain.run(n_iter=1000, RF=rf1)
select_index = np.arange(0,1000,100)
np.savetxt("name,txt", beds[select_index,:,:].reshape(len(select_index), -1))

# %% [markdown]
# And these data can be loaded later and concatenated together to showcase the complete chain

# %% [markdown]
# A chain can be continued by assigning the initial bed

# %%
largeScaleChain.initial_bed = beds[-1]

beds2, loss_mc2, loss_data2, loss2, steps2, resampled_times2, blocks_used2 = largeScaleChain.run(n_iter=5000, RF=rf1, rng_seed=rng, only_save_last_bed=False, info_per_iter = 100)

# %%
plt.pcolormesh(xx,yy,beds[-1] - beds2[0],cmap='viridis')
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx,yy,beds2[-1]-beds2[0],cmap='RdBu')
plt.axis('scaled')
plt.colorbar()

# %%
plt.pcolormesh(xx,yy,beds2[-1],cmap='gist_earth')
plt.axis('scaled')
plt.colorbar()
